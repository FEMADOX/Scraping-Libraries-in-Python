# %%
import pandas as pd

df = pd.read_csv("dia_products.csv", index_col="#")

# %%
# df.loc[df.duplicated(keep=False)]
# df.loc[df.duplicated(keep="last")].merge(
#     df.loc[df.duplicated(keep="first")],
#     on=["Price", "Price per Unit"],
#     suffixes=("_left", "_right"),
# )
#
# # Identificamos el primer y el último registro de cada duplicado
# first = df[df.duplicated(subset="Product Name", keep="last")]
# last = df[df.duplicated(subset="Product Name", keep="first")]
#
# # Hacemos el merge usando el NOMBRE como clave
# comparacion = first.merge(last, on="Product Name", suffixes=("_original", "_duplicado"))
#
# comparacion

# df[df.duplicated(subset="Product Name", keep=False)].sort_values(["Product Name","#"], ascending=True)
# df[df.duplicated(subset="Product Name", keep=False)].sort_values("#", ascending=True)

df
# Out:
#                                          Product Name  Price Price per Unit
# #
# 1   Jamón cocido extra Dia Nuestra Alacena sobre 2...  3,45€     7,67€/KILO
# 2   Pechuga de pavo Dia Nuestra Alacena sobre 2 x ...  3,95€     9,88€/KILO
# 3   Jamón cocido extra 97% Dia Nuestra Alacena sob...  1,99€    13,27€/KILO
# 4   Pechuga de pavo 92% Dia Nuestra Alacena sobre ...  1,99€    16,60€/KILO
# 5   Pechuguitas de pollo asado 99% La Carloteña ba...  2,19€    21,90€/KILO
# 6           Maxi York Dia Nuestra Alacena sobre 350 g  1,99€     5,69€/KILO
# 7                Pechuga de pavo Campofrío sobre 70 g  1,00€    14,29€/KILO
# 8   Jamón de pavo finas lonchas Dia Nuestra Alacen...  1,69€     9,39€/KILO
# 9   Lacón ahumado 97% Dia Nuestra Alacena sobre 150 g  1,69€    11,27€/KILO
# 10                       Maxi York Elpozo sobre 300 g  1,99€     6,63€/KILO
# 11  Pechuga de pollo braseado Dia Nuestra Alacena ...  2,29€    11,45€/KILO
# ...
